# %%
SELECT
name
FROM
custcmers;

# %%
SELECT
customer_id,
name
credit_limit
FROM
customers;

# %%
SELECT
customer_id,
name,
address,
website,
credit_limit
FROM
customers;

# %%
SELECT
UPPER( 'This is a string')
From
what_table;

# %%
SELECT * FROM dual;

# %%
SELECT
UPPER('This is a string ')
FROM
dual;

# %%
SELECT
(10 + s)/2
FROM
dual;

# %%
SELECT
column_1,
column_2,
column_3,
...
FROM
table_nane
ORDER BY
column_1 [ASC I DESCJ [NULLS FIRST I NULLS LAST],
column_1 [ASC I DESC] [NULLS FIRST I NULLS LAST],
...

# %%
SELECT
name,
address ,
credit_limit
FROM
customers;

# %%
SELECT
name,
address,
credit_limit
FROM
customers
ORDER BY
name ASC;

# %%
ORDER BY name ASC

# %%
ORDER BY name

# %%
SELECT
name,
address ,
credit_limit
FROM
customers
ORDER BY
name DESC;

# %%
SELECT
     first_name,
     last_name
FROM
     contacts
ORDER BY
    first_name,
    last_name DESC;

# %%
SELECT
   name,
   credi_limit
FROM
   customers
ORDER BY
2 DESC,
1;

# %%
SELECT
   country_id,
   city,
   state
FROM
   locations
   ORDER BY
      city ,
      state;

# %%
SELECT
    cenmtry_id,
city,
state
FROM
    locations
ORDER BY
state ASC NULLS FIRST;

# %%
SELECT
   country_id ,
   city,
   state
FROM
   locatims
ORDER BY
   state
ASC NULLS LAST;

# %%
SELECT
     customer_id,
     name
FROM
     customers
ORDER BY
UPPER(name),

# %%
SELECT
     order_id
     customer_id,
     status,
     order_date
FROM
   orders
ORDER BY
    order_date DESC;

# %%
SELECT DISTINCT colunn_l
FROM table;

# %%
SELECT
    DISTINCT column_1,
column_2,
column_3
FROM
table_name;

# %%
SELECT
   first_name
FROM
   contacts
ORDER BY
    first_name;

# %%
SELECT DISTINCT
   first_name
FROM
  contacts
ORDER BY
first_name;

# %%
SELECT
     DISTINCT product_id,
     quantity
FROM
     ORDER_ITEMS
ORDER BY
    product_id;

# %%
SELECT
     DISTINCT state
FROM
     locations
ORDER BY
     state NULLS FIRST;

# %%
SELECT
     select_list
FROM
     table_name
WHERE
     search_condition
ORDER BY
sort_expression;

# %%
SELECT
      product_name,
      description,
      list_price,
      category_id
 From
    products
WHERE
    product_name = 'Kingstom';

# %%
SELECT
      product_name,
      list_price
From
      products
WHERE
      list_price > 500;

# %%
SELECT
      product_name,
      list_price
FROM
      products
WHERE
      list_price > 500
AND category_id = 4;

# %%
SELECT
      product_name
      list_price
FROM
      products
WHERE
      list_price BETWEEN 650 AND 680
ORDER BY
      list_price;

# %%
list_price BETWEEN 650 AND 680
list_price 650 ANO list_price <= 680

# %%
SELECT
      product_name,
      category_id
FROM
     products
WHERE
     category_id IN(1,4)
ORDER BY
     product_name;

# %%
category_id IN (1, 4)

# %%
category_id = 1 OR category_id = 4

# %%
SELECT
      product_name,
      list_price
FROM
      products
WHERE
      product_name LIKE 'Asus%'

# %%
SELECT
     first_name,
     last_name
FROM
     employees
ORDER BY
     first_name;

# %%
SELECT
      Istprc,
      prdnm
FROM
   long_table_name;

# %%
SELECT
     first_name forename,
     last_namæ surnanæ
FROM
employees;

# %%
SELECT
     first_name "Forename",
     last_name "Surname"
FROM
    employees;

# %%
SELECT
      first_name "First Name",
      last_name "Fanily Name"
FROM
      employees ;

# %%
ORA_00923: FROM keyword not found where expected

# %%
SELECT
     first name  || ' ' || last_name
FROM
   employees;

# %%
SELECT
    first_name  || ' ' || last_name AS "FUll Name"
FROM
   employees;

# %%
SELECT
  product_name,
  list_price - standard_cost AS gross_profit
FROM
    products;

# %%
SELECT
    product_name,
    list_price - standard_cost AS gross_profit
FROM
    products
ORDER BY
    gross_profit DESC;

# %%
table_name AS table_alias
table_name table_alias

# %%
table_name. column_name

# %%
table_alias. column_name

# %%
SELECT
  e. first_name employee,
    m. first_name manager
    FROM
       employees e
       INNER JOIN employees m
       ON
         m. employee_id = e. employee_id;
